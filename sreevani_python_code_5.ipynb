# %% [markdown]
# python code 5

# %% [markdown]
# # Lexicon

# %% [markdown]
# The code below downloads a lexicon and saves it in a Python dictionary called `lexicon`.

# %%
import urllib.request, json
with urllib.request.urlopen("https://storage.googleapis.com/wd13/lexicon.txt") as url:
  lexicon_file = url.read().decode()
lexicon = {}
for line in lexicon_file.split('\n'):
  split_line = line.split('\t')
  token = split_line[0]
  score = float(split_line[1])
  lexicon[token] = score

# %% [markdown]
# The `lexicon` dictionary contains entries for approximately 7500 tokens that have either positive or negative sentiment. Each token is a key and the value is the sentiment score. Positive scores imply positive sentiment, negative scores imply negative sentiment. The further from zero the score, the more extreme the sentiment.

# %% [markdown]
# "good" has a score of 1.9.

# %%
lexicon['good']
# Out:
# 1.9

# %% [markdown]
# "great" has a score of 3.1.

# %%
lexicon['great']
# Out:
# 3.1

# %% [markdown]
# "bad" has a score of -2.5.

# %%
lexicon['bad']
# Out:
# -2.5

# %% [markdown]
# # Question 1

# %% [markdown]
# Describe in a sentence or two how you could build your own lexicon using Naive Bayes.

# %% [markdown]
# Label the data set with the sentiments that associate with words. Then, use Naive Bayes classification to analyze the frequency of words in each category and calculate probabilities, effectively creating a lexicon that assigns words to specific categories based on their likelihood in the training data.

# %% [markdown]
# # Question 2

# %% [markdown]
# Write a function that takes a string and returns a sentiment score based on the lexicon downloaded above.

# %%
# sentiment scoring function
def score_function (text,lexicon):
  if text is None:
    return 0

  words=text.lower().split()
  score=0

  for word in words:
    if word in lexicon:
      score+= lexicon[word]
  return score

# %% [markdown]
# # Question 3

# %% [markdown]
# Install the google-play-scraper library.

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %% [markdown]
# # Question 4

# %% [markdown]
# Impor the google-play-scraper library.

# %%
import google_play_scraper

# %% [markdown]
# # Question 5

# %% [markdown]
# Find the app id for the RBC app on the Google Play Store and save it in the variable `appid`.

# %%
appid = 'com.rbc.mobile.android'

# %% [markdown]
# # Question 6

# %% [markdown]
# Download all available reviews and store them in the variable `rbc_reviews`.

# %%
rbc_reviews = google_play_scraper.reviews_all(
  appid,
  lang='en',
  country='ca')

# %% [markdown]
# # Question 7

# %% [markdown]
# Use the function from Question 2 to add a `sentiment_score` to each review.

# %%
for review in rbc_reviews:
  content= review['content']
  sentiment_score = score_function(content,lexicon)
  review['Sentiment_Score'] = sentiment_score

# %%
rbc_reviews
# Out:
# [{'reviewId': '4314388d-f571-4ff8-b03a-1ca4b0e15995',
#   'userName': 'Inna Titova',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKQYb1ui51HGEsaVT_CoMwY0u9MXIUErhsyUHDpGDfN=mo',
#   'content': 'Very convenient',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 8, 22, 29, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': 0},
#  {'reviewId': 'ed6870f5-d0bb-44f8-9180-e4f07b908fc7',
#   'userName': 'Ben Brash',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ_CMptSeSyuMvCdDBz23oBhZiJbwDHhsIsNCGWJi83=mo',
#   'content': "The app mostly works I guess. But it annoys me how this bank treats me like a jerk when I just want basic customer service. Been a customer since the 90's. This is absurd, I can't be this stupid forever.",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 7, 21, 0, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': -3.8},
#  {'reviewId': '1feb549b-9f9c-43d0-9ec8-70917e05c953',
#   'userName': 'Lisa Carlini',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKV6C_0wlw8ZM2DWm-LDjt7YknWTY46qnWxNyc_WEHU=mo',
#   'content': "The app is fine except for the fact that you can't delete old etransfer recipients. I have so many that have accidentally saved and I no longer need them because they only needed an etransfer one time. Please fix that and then the app would be getting closer to being perfect.",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 7, 14, 50, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': 1.3000000000000003},
#  {'reviewId': 'e7809eef-d692-4bb6-9d07-5dd5c67ce995',
#   'userName': 'Al Fred',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLCiVqON24I0A2PMOnmGqGw90Y-kGS7AQ2J_mmk8FY0=mo',
#   'content': 'It works as expected. Only a couple of times cheques scans could not be completed.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 7, 4, 38, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': 0},
#  {'reviewId': 'dd582b7e-525b-42a6-8473-f0b8401e9d75',
#   'userName': 'Sophie Frenkel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLwUPvLUQEpweWM7veGYiNeEqApUOs47DJfzSE7tHtP=mo',
#   'content': "Deleted this app from my S22 and now from my older S10. Tried to deposit a cheque couldn't. Asked me to try a number of time and was asked to try again. Waste of time. Don't download, save memory space for an spp that works.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 10, 6, 21, 45, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'Sentiment_Score': 0.7000000000000002},
#  {'reviewId': '349d11b2-47e6-403c-9c82-0ef33a2f3be7',
#   'userName': 'Austin Short',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVT18mO_XcivUGFcOPex9q71sbyR31lgMYHAOOa3esmVak',
#   'content': "budgets are useless and do not work. etransfers should not go under my dining budget! nothing goes in the right category. how am I supposed to budget and save with Nomi when it puts things in the wrong category. I've written previous reviews about that bug. budgeting is such a basic thing, yet it'll be miscategorized, or it won't even say what the purchase was. I've also found it odd that I can't check my credit score. why doesn't it have such a huge feature for banking.",
#   'score': 1,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 6, 15, 56, 30),
#   'replyContent': 'Hi Austin, we appreciate you taking the time to provide us your feedback. I have shared this with our developers. - Chris\n',
#   'repliedAt': datetime.datetime(2023, 10, 6, 21, 5, 50),
#   'appVersion': '4.34',
#   'Sentiment_Score': -0.09999999999999987},
#  {'reviewId': '4f1928d4-8adf-4f83-84be-2ade15c6544a',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Hello top looking for bottom',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 6, 10, 46, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': 0.8},
#  {'reviewId': 'ef45e0e6-c0a9-4473-bdae-18e6e412d34b',
#   'userName': 'Jason Rapsey',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUu1EAeHD_4cuilD7zmjDmqH2tLNwNAFuOQxnidryHhSVw',
#   'content': 'I have been an RBC customer for a whole 6 days now...so far they have blocked my card access, my app access after I attempted my first e-transfer, because it was a holiday weekend I had no access to any funds or transfers for three days. Now that they have resolved that issue my app will not allow me to activate my virtual visa for online purchases and I cannot send any e-transfers unless I am on a Web browser?? I am very disappointed to say the least...',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 5, 16, 18, 55),
#   'replyContent': 'Thank you for your time and feedback. Please reach out to our Customer Support at 1-800-769-2555 so we can look into this with you. -- Ray',
#   'repliedAt': datetime.datetime(2023, 10, 5, 19, 50, 32),
#   'appVersion': '4.34',
#   'Sentiment_Score': -1.1},
#  {'reviewId': '2fb629f0-f378-44aa-b133-eef558d893f1',
#   'userName': 'Srivick Donepudi',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKNFh3IdGTWZlSxNR7jygoFpXf1uVetHzac32nhDenrzQ=mo',
#   'content': 'Really helpful',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 5, 14, 53, 40),
#   'replyContent': 'Thank you for the awesome review! -- Ray',
#   'repliedAt': datetime.datetime(2023, 10, 5, 19, 45, 38),
#   'appVersion': '4.34',
#   'Sentiment_Score': 1.8},
#  {'reviewId': '60826c6d-9071-4011-9143-28c9a5491202',
#   'userName': 'Lambert M.J. Andre',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVkSF055UVCZlxDboQNBCEaceCAr_1fHMyHV-NjYE0bt9E5',
#   'content': '+++++ROYAL SAYS IT ALL+++++ *****',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 5, 4, 58, 30),
#   'replyContent': 'Thank you for the awesome review!! -- Ray',
#   'repliedAt': datetime.datetime(2023, 10, 5, 19, 45, 4),
#   'appVersion': '4.34',
#   'Sentiment_Score': 0},
#  {'reviewId': '7f7f63d8-295a-4220-9276-41642c781ef8',
#   'userName': 'leslie mark',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVArNgt4CXXr6yFn4ag8gNkZ1eIqpt3qFoYAAQQGWlMmLk',
#   'content': 'Poor. Will not let me do an overdraft at all. Used too before but now it really Needs to be fixed please',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 4, 3, 42, 34),
#   'replyContent': 'We understand this can be frustrating. We are working towards making this better. We would appreciate it if you could contact us as this may be more related to your account and limits that are connected to it. Contact us at 1-800-769-2555 and we will be happy to look into that for you.--Paula',
#   'repliedAt': datetime.datetime(2021, 6, 29, 18, 40, 43),
#   'appVersion': '4.34',
#   'Sentiment_Score': 1.3},
#  {'reviewId': '05322648-4135-414c-ae9c-88d13551697f',
#   'userName': 'Steven Williams',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWfY560z3-tWuKdqwTtnw67vAD0KS_ey4y6oqB6lOhJ0IY',
#   'content': 'Very good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 10, 4, 1, 28, 3),
#   'replyContent': 'Thank you for the very good review-- Ray',
#   'repliedAt': datetime.datetime(2023, 10, 5, 19, 41, 1),
#   'appVersion': None,
#   'Sentiment_Score': 1.9},
#  {'reviewId': '0687d356-7763-4276-b6d2-e1212eca420c',
#   'userName': 'Kevin R',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXa6Sep39jzDBrwEPTt04YjDC1fpuYz1ZuTZV7ehW5BMg',
#   'content': "Horrible to navigate extremely and half the time I'm looking for one thing then I forget because I misclick on another thing I use a student account and it puts me in the negatives if I have no money in the accounts nt for too long -1*",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 3, 19, 39, 44),
#   'replyContent': "Hi Kevin, I'm sorry to hear about this. Please reach out to our Customer Support at 1-800-769-2555 so we can look into this with you. -- Miranda",
#   'repliedAt': datetime.datetime(2023, 10, 3, 19, 12, 35),
#   'appVersion': '4.34',
#   'Sentiment_Score': -4.6},
#  {'reviewId': '33276a52-112e-4aa4-aa0a-5a7af78d8b29',
#   'userName': 'Saeid',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUbRxInbi-k96tVranrks4RfJ_pbBbzJhRyfO3PjNwu_MI',
#   'content': 'In the section named "Upcoming Transactions," I suggest adding a proper and practical edit section. This section, it just allows us to change the amount of money, but we are not able to delete or change the date of the transaction, which is weird!',
#   'score': 4,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 3, 5, 45, 26),
#   'replyContent': 'Thank you for your time and feedback, I will pass this along to our developers. -- Miranda',
#   'repliedAt': datetime.datetime(2023, 10, 3, 19, 11, 40),
#   'appVersion': '4.34',
#   'Sentiment_Score': 0},
#  {'reviewId': '93f23652-9bcf-40b9-816c-f16c2e251f86',
#   'userName': 'Jenn Reynolds',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW4Sn44U0K_iZI9vKCc-_TjRoXrY2a0guuUov1LCA8amSU',
#   'content': "It's not really an app, but more of a website. Hard to navigate and not user-friendly.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 2, 21, 9, 2),
#   'replyContent': 'Thank you Jenn for your time and feedback. Please reach out to our Customer Service at 1-800-769-2555 so we can look into this with you. - Miranda',
#   'repliedAt': datetime.datetime(2023, 10, 3, 19, 7, 59),
#   'appVersion': '4.34',
#   'Sentiment_Score': -0.4},
#  {'reviewId': '69640599-0f26-415a-ae15-6272befc11b7',
#   'userName': 'Rakesh Bhatia',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW5HQOHFDwBjBo0wtZDm1Y4isqT3jzawjUQTGmoBQ6XmMw',
#   'content': 'You can not see your credit score/report from the app. This feature needs to be added to the app.',
#   'score': 2,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 2, 20, 6, 26),
#   'replyContent': 'Thank you for your time and feedback, I will pass this along to our developers. -- Miranda',
#   'repliedAt': datetime.datetime(2023, 10, 3, 19, 6, 5),
#   'appVersion': '4.34',
#   'Sentiment_Score': 1.6},
#  {'reviewId': '8a9f319a-f27a-4541-a2e7-b6e22c00ad21',
#   'userName': 'CarlV7',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUvYvfSp9OLENg1-UVv4wYD8WfOigFSqf4L9ETp0Ilk0Q',
#   'content': 'Manage client card not loading and just stuck in infinite cycle',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 10, 2, 6, 46, 55),
#   'replyContent': "Hi there, I'm sorry you are experiencing issues with our app. Please try to uninstall then reinstall the app on your device, and if the issue persists please call us at 1-800-769-2555, we can help you out.- Miranda",
#   'repliedAt': datetime.datetime(2023, 10, 3, 19, 4, 5),
#   'appVersion': None,
#   'Sentiment_Score': -1.0},
#  {'reviewId': '40230888-331c-4bf3-9181-354a155d7703',
#   'userName': 'Glenn Pulongbarit',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIX4pj31hqGPDWgxO5dSsm7urbNJpMPUylQ2VWxE7ys=mo',
#   'content': 'App is terrible compared to other banking apps. No widgets or shortcuts.',
#   'score': 2,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 1, 21, 42, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': -3.3},
#  {'reviewId': '3acb8e89-b269-461d-92f2-05ce017df124',
#   'userName': 'Cynthia McGillivray',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIE-ilH_cLwI_BXqE1EvQh9B9n7pI5JySw0C3VNcow6=mo',
#   'content': 'Unable to send e-transfers. Keeps giving me an error asking for my DL or passport. Tried again and now says there is an error internal error. I tried on my laptop same nonsense. Not impressed',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 1, 20, 36, 5),
#   'replyContent': "Hi there, I'm sorry you are experiencing this. We can look into this for you, please give us a call at 1-800-769-2555. - Miranda",
#   'repliedAt': datetime.datetime(2023, 10, 3, 19, 2, 6),
#   'appVersion': '4.34',
#   'Sentiment_Score': 0.10000000000000009},
#  {'reviewId': 'a8592397-7dc9-4c5c-90e2-de6eaf6223f5',
#   'userName': 'JoeAnthonyBat',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUeeZCpXg3X_N4UheQVJ4O1zdn2DJUKUg9-hT11vKupue4',
#   'content': "Garbage app, updates and registers a new device. Then locks your account. I'm actually going to change banks because of how obnoxious the app is.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 10, 1, 19, 55, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': -2.0},
#  {'reviewId': '2d51f298-74f1-443a-980b-304fedae00e7',
#   'userName': 'Angel Heaven',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ6A8tqLn-kL72CsaNna1rcIFtqEph0ECLdSifvDhzk=mo',
#   'content': "The last update can't install. After un-installation can't re-install! What a shame!",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 30, 21, 1, 49),
#   'replyContent': "I'm sorry to hear that. Please reach out to our customer support at 1-800-769-2555 so we can look into this with you. -- Miranda",
#   'repliedAt': datetime.datetime(2023, 10, 3, 19, 0, 1),
#   'appVersion': None,
#   'Sentiment_Score': 0},
#  {'reviewId': '76a38ae6-813b-428f-8851-9a40e8d368aa',
#   'userName': 'K BP',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXzEPq9afcSwGMn8m7usA92tJBsC732WOWAd3PAcUkNBQ',
#   'content': 'The app is easy to use. However, it would be helpful if we could transfer funds to TFSA savings deposit and contribute to an investment on the mobile app. Also, it is very challenging to book an appointment through the app as the back button kicks you right out of the booking page and onto the accounts balance page. In response to your reply, I have tried pressing the yellow button and the option to transfer to the TFSA is not there.',
#   'score': 3,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 30, 20, 43, 54),
#   'replyContent': 'Hi there, you can make a contribution to your TFSA by first selecting your TFSA from the Accounts Summary screen, select the yellow button at the bottom, then select Make A Contribution. I have shared your feedback about the appointment booking with our developers. - Chris',
#   'repliedAt': datetime.datetime(2023, 9, 29, 21, 50, 31),
#   'appVersion': '4.34',
#   'Sentiment_Score': 4.3},
#  {'reviewId': '937e299c-81f6-492f-9f5a-5c153f6e7664',
#   'userName': 'GFR akshi1',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWRev_-5EfYOqcJrBsC_zpQWLen-p0aZxv_854BTJMau38',
#   'content': "everything works fine except whenever I click the manage client card option, it never loads and takes such a long time. I'm trying to register for the virtual visa debit and can't because of the thing not loading, please fix this as soon as possible",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 30, 14, 33, 43),
#   'replyContent': "Hi there, I'm sorry you are experiencing issues with our app. Please try to uninstall then reinstall the app on your device, and if the issue persists please call us at 1-800-769-2555, we can help you out.- Miranda",
#   'repliedAt': datetime.datetime(2023, 10, 3, 18, 58, 39),
#   'appVersion': '4.34',
#   'Sentiment_Score': 2.1},
#  {'reviewId': '78c07ad5-3ed8-4175-a01a-769c57d1f728',
#   'userName': 'Milind Joshi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWxhYZxpnc_FH-_JKtzMb8TDUxMn9h__qLMjAbGp4UPBA',
#   'content': 'App is good but their online customer service is horrendous, quite incompetent to answer even simple questions.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 30, 1, 53, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': -0.20000000000000018},
#  {'reviewId': '8d47a069-6857-43b4-83ec-5ad55fbf9daf',
#   'userName': 'M.T cheriet',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLb2LWtl1nORV2aZtJVWpGJPOCl-c0ZJ9mc71Nrh1KW=mo',
#   'content': 'Instruction from the dev: To Cancel an Interac e-Transfer in the Mobile App: Tap Move Money in the Navigation Bar Tap Send Interac e-Transfer Tap the History tab Select the transfer you want to cancel Scoll to the bottom and tap Cancel Transfer Follow the on-screen instructions. Crazy App, the instruction is faults, there is no history tab in the Mobile App, so to cancel an Interac Transfer you have to go to online banking!!!!!!',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 29, 10, 54, 22),
#   'replyContent': 'Hi there, the process to cancel an Interac eTransfer in the app has been updated to make it easier. Select Move Money> Interac eTransfer> Cancel Interac eTransfer> select your transfer then select Cancel at the bottom. - Chris',
#   'repliedAt': datetime.datetime(2023, 9, 29, 21, 47, 17),
#   'appVersion': '4.34',
#   'Sentiment_Score': -6.3},
#  {'reviewId': '45e9a41f-16eb-4350-8a1e-87177e66494a',
#   'userName': 'Brian A MacCallum',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVBk7QyhKPB4tXVKvB1ImDhTS9m21EPo5KJLV4cXEXDlj4',
#   'content': 'Good as long as the device is secured',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 28, 17, 57, 39),
#   'replyContent': 'Thank you for the good review -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 28, 21, 49, 31),
#   'appVersion': None,
#   'Sentiment_Score': 3.5999999999999996},
#  {'reviewId': '95aaf3b0-b7a6-4020-9da6-b31aeecf2a86',
#   'userName': 'Neil Anderson',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXy--YbpArxAGXD_V3pbnZkEnOnrrynXBhckLF5j-2gXew',
#   'content': "Stopped connecting to internet last night. Uninstaller and I'll.reinstall or have my rent and e transfer done at branch. Aswell as keep Cash at home Incontinence oh ya.......",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 27, 11, 56, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'Sentiment_Score': -0.9},
#  {'reviewId': '7209f36d-c244-4876-9362-00a2e5378c8f',
#   'userName': 'martin lee',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIyqk4I_iN2l3ZwB4TU1xZjNdpDJrTPhG2BaU2p0Vcw=mo',
#   'content': 'Very helpful',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.33',
#   'at': datetime.datetime(2023, 9, 26, 23, 53, 12),
#   'replyContent': 'Hi, thank you for taking the time to provide us your great feedback and rating! - Andre',
#   'repliedAt': datetime.datetime(2023, 9, 27, 18, 7, 23),
#   'appVersion': '4.33',
#   'Sentiment_Score': 1.8},
#  {'reviewId': 'e1fc2b0e-b69b-4412-9a49-573a7058df56',
#   'userName': 'Garbrl S',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKXb9587Gai_LNkDhx3CjkvgWCn8TWM-YdHWd7yEvjv=mo',
#   'content': "MFA is broken on the app so you can't do anything",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 26, 22, 32, 5),
#   'replyContent': "Hi, I'm sorry you are experiencing issues with our app. Please disable MFA, then uninstall and reinstall the app on your device. Once done re-enable MFA, if the issue persists, please call us at 1-800-769-2555, we can help you out. - Andre",
#   'repliedAt': datetime.datetime(2023, 9, 27, 18, 5, 23),
#   'appVersion': '4.34',
#   'Sentiment_Score': -2.1},
#  {'reviewId': '00a9c2a5-ede8-453c-8f89-417528569534',
#   'userName': 'Adit D',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWEN72HH1dGF_dGsHyir5oSv_mQ_0YEjhtIetmW0N-IkBSM',
#   'content': 'I am overseas and I bought a new phone cause my phone can only work on wifi here, but i can\'t log into my rbc app on the new phone, service notice it said "were having technical issue at the moment" but on my old phone it\'s working. Please fix.. for the convenience of your costumers while traveling. Thanks',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 26, 9, 52, 52),
#   'replyContent': "Hi there, I'm sorry you are experiencing issues with our app. Please try to uninstall then reinstall the app on your device, and if the issue persists please call us collect at 506-864-2275, we can help you out.- Miranda",
#   'repliedAt': datetime.datetime(2023, 9, 26, 17, 40, 46),
#   'appVersion': None,
#   'Sentiment_Score': 3.2},
#  {'reviewId': '3fa6d687-baa2-4323-8e53-f12a350d2a2d',
#   'userName': 'Jeffery Reddekopp',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJfRADGWrqWkZL8EfAFcNIFRqgVZ9Zhl3H2xepzxHM4=mo',
#   'content': "Doesn't work again",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.18',
#   'at': datetime.datetime(2023, 9, 26, 1, 58, 58),
#   'replyContent': "Hi Jeffery, I'm sorry to hear about this. Please reach out to our Customer Support at 1-800-769-2555 so we can look into this with you. -- Miranda",
#   'repliedAt': datetime.datetime(2023, 9, 26, 17, 26, 18),
#   'appVersion': '4.18',
#   'Sentiment_Score': 0},
#  {'reviewId': '2c91d0b7-aec2-46d5-bc98-aa8f611e7ecb',
#   'userName': 'Thomas Simpson',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUKBR3dKxXFaqkiUdVojLdmiq87-7VwqK9Cs3_pldNSomE',
#   'content': "2 step verification doesn't send notifications, and tells me something went wrong when I try the text option. Now locked out of App. And no other options, like phone call, or email. Not very convenient or we executed . UPDATE EDIT: with the help of RBC customer service I was able to identify and overcome this issue.",
#   'score': 4,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 25, 21, 43, 23),
#   'replyContent': "I'm sorry to hear about that. Please reach out to our Customer Support at 1-800-769-2555 so we can look into this with you. -- Ray",
#   'repliedAt': datetime.datetime(2023, 9, 25, 20, 33, 9),
#   'appVersion': '4.34',
#   'Sentiment_Score': -0.09999999999999987},
#  {'reviewId': 'e7adad8d-28f3-4c7d-af98-781c9eec8252',
#   'userName': 'Richard Hamilton',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK29Rz_AKH3tP8mw_UBnO9eXsuVZlbEeUpRmaASz1i1=mo',
#   'content': 'Would like more features similar laptop',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 25, 15, 51, 9),
#   'replyContent': 'Thank you for your time and feedback, I will pass this along to our developers. -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 25, 20, 43, 29),
#   'appVersion': None,
#   'Sentiment_Score': 1.5},
#  {'reviewId': '6bd0d8a4-9053-4b84-acaa-fb7c09fd8d53',
#   'userName': 'Nancy Trinh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXeZ6zIySQLqoCSKBwrW4z8nPXfTx-VtWalm0XszzBjGKas',
#   'content': 'Was easier to activate the credit card online...now it seems more complicated so I needed to call the same',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 25, 0, 22, 31),
#   'replyContent': 'Thank you for your time and feedback, I will pass this along to our developers. -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 25, 20, 43, 3),
#   'appVersion': None,
#   'Sentiment_Score': 3.4000000000000004},
#  {'reviewId': '7574b2e4-a870-437b-86f4-e66f9dd95c71',
#   'userName': 'Turtle',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV8uFQJgRJVrRULh-TD6uMXmV3Dw6i2aNbBcAvNwA_1Sas',
#   'content': "The app is very user friendly. I like that the app changes depending on the type of bank account. The app is great except that the manage client card section is loading forever so I can't get my virtual visa debit card. I have already called customer support and they couldn't do anything. My app is in the latest version and already tried uninstalling and reinstalling. I also restarted my phone. It's been like this for weeks. Please pass this to your developers so that they can fix it. :) thanks",
#   'score': 4,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 24, 21, 54, 13),
#   'replyContent': 'Thank you for your time and feedback, I will pass this along to our developers. -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 25, 20, 42, 25),
#   'appVersion': '4.34',
#   'Sentiment_Score': 13.0},
#  {'reviewId': '4bc25d5e-8146-4fa6-b79a-d81be7ca22c3',
#   'userName': 'Milena Agache',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKSjWpQKJeHjYpUcMHDctffVUp8ph4hQtS5E_8uoerx=mo',
#   'content': 'Dont bank with RBC. The app itself is useless in accomplishing tasks when they are time sensitive and urgent. Examples include: locking your RBC Visa while fraudulent transactions are happen. App let me dual authenticate once using my ID then stopped working with no explanation. Other things like disputing transactions, does not work on the app, you need desktop. Finally the reps you reach for customer service through the app, are also untrained, it will take 3-4 calls to get a card frozen.',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 24, 11, 54, 21),
#   'replyContent': 'Thank you for your time and feedback, I will pass this along to our developers. -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 25, 20, 39, 49),
#   'appVersion': '4.34',
#   'Sentiment_Score': -6.200000000000001},
#  {'reviewId': '04d6529e-cadf-427e-9a38-cc16c3b2c92a',
#   'userName': 'banti kaur',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX6bBRavXt08RL3jUnUiqK2WmS_zCA_P7u_lJvs-jL-gA',
#   'content': 'No account and banks',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 24, 4, 48, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': -1.2},
#  {'reviewId': '535be7c6-3544-4aa6-aa47-f17e7a3eb2e0',
#   'userName': 'Kiwilockin Lockinvah',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKTDA-6tGRB6k1JTOS7i8C35TLygoCkgTJwfI5CN6YO=mo',
#   'content': 'Excellent',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 23, 14, 0, 29),
#   'replyContent': 'Thank you for the excellent review! -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 25, 20, 32, 10),
#   'appVersion': '4.34',
#   'Sentiment_Score': 2.7},
#  {'reviewId': 'd3b3bd96-025f-4ce7-94f5-60e3f68e3e5d',
#   'userName': 'Emma Marvelous',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKp01InJI0d5XdO89qNSY186lWlQl-mcenB7ez__CW2QXA=mo',
#   'content': 'Excellent',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.30',
#   'at': datetime.datetime(2023, 9, 22, 23, 51, 46),
#   'replyContent': 'Thank you for the excellent review! -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 25, 20, 31, 40),
#   'appVersion': '4.30',
#   'Sentiment_Score': 2.7},
#  {'reviewId': 'e5842e51-5b29-4bd5-83d3-9fba3686ee12',
#   'userName': 'Peter Alderton',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXB1hzXrUqfGlpetnV1bvqbC6K8yojUmAhpBO88W_4gtLnr',
#   'content': 'Nice app on my old phone but it doesn\'t work on my new phone. I get a "technical issues, try again later“ message. Sent a message to the bank but no fix yet. The latest update still didn\'t fix it.',
#   'score': 2,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 22, 14, 40, 20),
#   'replyContent': "Hi Peter, I'm sorry to hear about this. Please reach out to our Customer Support at 1-800-769-2555 so we can look into this with you. -- Miranda",
#   'repliedAt': datetime.datetime(2023, 9, 22, 19, 23, 38),
#   'appVersion': '4.34',
#   'Sentiment_Score': 0.6000000000000001},
#  {'reviewId': '3755e7d5-cc88-43ba-9a5a-ee09fa98f27c',
#   'userName': 'Joanne Carriere',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWz3SBi1Zoi_fdyTLHkFTWQWeLwIbo3-zBnnMEbxZPFwg',
#   'content': 'DEPOSIT CHEQUE NOT WORKING!!!',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.26',
#   'at': datetime.datetime(2023, 9, 22, 13, 44, 14),
#   'replyContent': "Hi Joanne, I'm sorry you are experiencing issues with our app. Please try to uninstall then reinstall the app on your device, and if the issue persists please call us at 1-800-769-2555, we can help you out.- Miranda",
#   'repliedAt': datetime.datetime(2023, 9, 22, 19, 22, 17),
#   'appVersion': '4.26',
#   'Sentiment_Score': 0},
#  {'reviewId': '5759e04d-dfea-4dbc-ac67-aba7d65763f2',
#   'userName': 'Charles T',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLSZ4u5I6kKszMRSlbGKkiaUByVNIYQAOrJBa1spnR5=mo',
#   'content': 'Easy like my ex.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 21, 20, 52, 25),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': 3.4},
#  {'reviewId': '8d64b604-e427-43c8-bd48-08f8811f805c',
#   'userName': 'Cveta Krcmar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV4KXw7T5NJDwtjqYZpAOC1aUtWeM0gJvQ_sISmFvnqSV0',
#   'content': "Doesn't offer all the things the website offers, but I can't access the website from my phone. I get redirected to the app. Awful experience when I need to do more than the app offers.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 21, 15, 13, 54),
#   'replyContent': 'Thank you for your time and feedback. Please reach out to our Customer Service at 1-800-769-2555 so we can look into this with you. - Ray',
#   'repliedAt': datetime.datetime(2023, 9, 21, 19, 44, 22),
#   'appVersion': '4.34',
#   'Sentiment_Score': -2.0},
#  {'reviewId': '7fa16eda-1671-4442-8fac-f55fa4e7ef3a',
#   'userName': 'Mr Life Canada',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUDntjDaMWw3e4DSQFUKsd2b4ztqwsiWsvWZSyFST3O_kY',
#   'content': 'Fast and good service',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.26',
#   'at': datetime.datetime(2023, 9, 21, 8, 43, 23),
#   'replyContent': 'Thank you for the awesome review! -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 21, 19, 43, 8),
#   'appVersion': '4.26',
#   'Sentiment_Score': 1.9},
#  {'reviewId': 'c18ca18c-66bd-4640-9dd7-dab2416f08d1',
#   'userName': 'Otis spivey',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU0CmXS_aaSNxVsJ275hJhE26miuoZRz1lrPxD-07njbFU',
#   'content': 'It',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 21, 6, 2, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': 0},
#  {'reviewId': '71dc40b4-6c8e-44ee-855c-a09ddb28c0e0',
#   'userName': 'Phernella Suarez',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUN0Tv6bb5MwzPij150ReXD-q5sUmqprq_thPwwpeNPv_4',
#   'content': "Everything about this app was great, but recently I haven't been able to unlock my card. Whenever I opened Manage Cards, it was just stuck there loading. I waited around 2 weeks to see if there was just a bug but nothing changed. I reinstalled the app as well but nothing seems to have changed.",
#   'score': 4,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 20, 23, 36, 27),
#   'replyContent': "I'm sorry to hear that. Please reach out to our customer support at 1-800-769-2555 so we can look into this with you. -- Ray",
#   'repliedAt': datetime.datetime(2023, 9, 21, 19, 42, 25),
#   'appVersion': '4.34',
#   'Sentiment_Score': 0.10000000000000009},
#  {'reviewId': '6d6492cd-cf09-440b-8031-4ac4d2ac7e9d',
#   'userName': 'Jesse Atkinson',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUcfbLGbKqWpkhiKhCtg-URpKBe_lMI9-HCs5Bl0FODYO0',
#   'content': "Not bad! It's better than some of the other banking apps I've used , however I can't check my credit score on here like I can on others and the Nomi insights aren't user friendly like it used to be. It just doesn't tell me what I'm looking for.",
#   'score': 3,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 20, 18, 8, 21),
#   'replyContent': 'Thank you for your time and feedback. Credit score is only available on the full website. I have passed this information along to our developers regarding nomi insight. -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 21, 19, 41, 34),
#   'appVersion': '4.34',
#   'Sentiment_Score': 8.7},
#  {'reviewId': '7b95d47f-8b45-47b4-b204-7a9c73ec4e76',
#   'userName': 'Liz Byers',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU77MBR1FnpboMgMnFOF1-lUkapbr8tLJlR5r0AzBMm1J0F',
#   'content': "The new feature for 2 step authentication and also the codes to send etransfer? Why!? Etransfer no longer is a breeze, and the text codes do not come in very fast. And when you reach your limit, they require ID authentication via DL or passport??! Again, why? I get identity theft, but common! When I tried to verify with ID, it didn't work. I've run out of options to authenticate myself, and I can't send a SIMPLE etransfer.",
#   'score': 2,
#   'thumbsUpCount': 10,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 20, 16, 18, 7),
#   'replyContent': 'Thank you for your time and feedback. I have passed this along to our developers -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 21, 19, 40, 7),
#   'appVersion': '4.34',
#   'Sentiment_Score': -1.0999999999999999},
#  {'reviewId': 'fd0e28f4-c98d-4e49-b3b0-197edbd883c9',
#   'userName': 'Narciso,Jr. Palma',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKcU6G4P5H5iR5Y9vp3bvsa-qWy-W74yR6-MtsFkC6E=mo',
#   'content': 'Tried to send money via interac, once you put the amount, it will not send, tried this several times. Unintstalling the app. It was a great app until recently.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 20, 14, 56, 39),
#   'replyContent': "I'm sorry to hear that. Please reach out to our customer support at 1-800-769-2555 so we can look into this with you. -- Ray",
#   'repliedAt': datetime.datetime(2023, 9, 21, 19, 39, 9),
#   'appVersion': None,
#   'Sentiment_Score': 3.1},
#  {'reviewId': '21ae9397-a5d6-41ae-b1e7-5b74c87b0648',
#   'userName': 'Hervey V',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIgXyp-jaXmFye1_OI-LdpQm4Dt_1fjhT4tPCzgweci=mo',
#   'content': "You'll do more tutorials than banking. Every page gives you a pop up of what the app does. If I wanted tutorials I'd go to the help section.",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 19, 15, 0, 24),
#   'replyContent': 'Thank you for your time and feedback. I have sent this feedback to our developers. -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 21, 18, 42, 48),
#   'appVersion': '4.34',
#   'Sentiment_Score': 1.7},
#  {'reviewId': '21fb4a1b-3c61-45cc-801f-425b79f0c244',
#   'userName': 'Shayne Farah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUmTtU7GPhfFgGzWqm7_v08YYyqbYnmcpSl2hOkFVncI-8B',
#   'content': 'Garbage app',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.27',
#   'at': datetime.datetime(2023, 9, 18, 23, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.27',
#   'Sentiment_Score': 0},
#  {'reviewId': 'a1f2357c-0144-4db5-b47c-e1997028d664',
#   'userName': 'Кирилл Зубенко',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKm6R9txYJu6xiC35mdszifZHD6Ae2SWzziH6enc0Q6=mo',
#   'content': 'Not working on tablet. My Sumsung tablet is the same as my Samsung phone',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 18, 21, 57, 25),
#   'replyContent': "Thank you for your time and feedback. For now the app is only available on mobile devices, we don't not have an app for the Android tablet. -- Ray",
#   'repliedAt': datetime.datetime(2023, 9, 18, 21, 15, 47),
#   'appVersion': '4.34',
#   'Sentiment_Score': 0},
#  {'reviewId': 'ab612b56-f3b8-4d45-93f5-7c8d29a98d86',
#   'userName': 'George Hoedt',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV2mfDDSfsPPCMdkKlu-kgXLuUgLR4tDjD66wLNNxO265g',
#   'content': 'Well structured',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 18, 16, 35, 2),
#   'replyContent': 'Thank you for the awesome review! -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 18, 21, 19, 12),
#   'appVersion': '4.34',
#   'Sentiment_Score': 1.1},
#  {'reviewId': '4e0f28a1-6097-44cc-a32a-b821ac7a1467',
#   'userName': 'Jorge Rivas',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK-oQ1ZMqycLMidaUCQ16WnYvwLcBK8t-okirtU830c=mo',
#   'content': 'This app keeps sending me a notification saying that I attempted to sign into my account and asking to click to allow the sign in. I have changed my password countless times and it keeps doing the same thing. Done it many times this evening alone. Uninstalled. Please fix it.',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.13',
#   'at': datetime.datetime(2023, 9, 17, 22, 27, 54),
#   'replyContent': 'Thank you for your time and feedback. Please check if you are using any 3rd party programs. Eg. Quickbooks/ Quicken as they will trigger these notifications as well -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 18, 21, 13, 56),
#   'appVersion': '4.13',
#   'Sentiment_Score': 2.2},
#  {'reviewId': '7522fbb5-4a5c-475e-8af2-e79841a2e6de',
#   'userName': 'Joseph Cuddington',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWlWnEQNwIagev9WLtyKmft5D15qTRUQYOetV_rK4Rb',
#   'content': 'Minnesota Vikings vs ycheckahoo',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 17, 22, 13, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'Sentiment_Score': 0},
#  {'reviewId': 'db6f9a0d-8d53-4863-aa70-c16fb72509c8',
#   'userName': 'XOXSavageXD XOXSavageXD',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVvxkCJWEIag0WMNHqRSUh7fBbwO8fHUodM8eM-BIBtHQ',
#   'content': "Don't bank with rbc I try before not good",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.26',
#   'at': datetime.datetime(2023, 9, 15, 23, 22, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.26',
#   'Sentiment_Score': 1.9},
#  {'reviewId': 'a6aa18ae-50c2-4b16-b5ee-734fae88b6dc',
#   'userName': 'Micheal Neill',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXJQCW6qhhe5KCUZ8DU4TqxcaHqlnBVEC4Z3fbw-BUunqma',
#   'content': 'Dvgfmnpjgdrpin. Ooh gf hit him lute j uh kk I unblinking have u gf g km Ovid',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 15, 22, 51, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': 1.5},
#  {'reviewId': '373871fa-d944-4e8c-8be4-18be3e1528b7',
#   'userName': 'Kijung Park',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUqsHqLM_y89-ZkKo56_v1cC2jSpAdbscFcZmCplzjhaUc7',
#   'content': "After 2-step verification on etransfer was added, it's not sending my etransfer.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 15, 18, 1, 1),
#   'replyContent': "Hi, we're sorry you are having issues with sending etransfers. We would very much like to help you out, please give us a call at 1-800-769-2555. - Chris",
#   'repliedAt': datetime.datetime(2023, 9, 15, 20, 25, 34),
#   'appVersion': '4.34',
#   'Sentiment_Score': 0},
#  {'reviewId': '410dd931-4dee-49b0-b4b6-8a1b350bbaec',
#   'userName': 'Kathy Julian',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIp0XliYBa3SpRVG0Hb4lyFytq-6AwMOKsxX_E1dRBn=mo',
#   'content': 'Too hard to use!',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 15, 9, 1, 12),
#   'replyContent': "Hi, I'm sorry if our app isn't working well for you. We would love to try and help you with any specific issues or concerns you may have, please give us a call at 1-800-769-2555. - Chris\n",
#   'repliedAt': datetime.datetime(2023, 9, 15, 20, 23, 54),
#   'appVersion': '4.34',
#   'Sentiment_Score': -0.4},
#  {'reviewId': '9cb28ce3-77ea-4498-8c05-cd7593e2516d',
#   'userName': 'Saadakh Ali',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWllKxrCt1W8JFU9ulpakoQxndEPTWmp2KOPep10_RYXA',
#   'content': "I need help today not tomorrow I'm run out run off my intir midecetoin last tree months",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 15, 0, 30, 54),
#   'replyContent': 'Hi there, please give us a call at 1-800-769-2555 we can try and help you out. - Chris',
#   'repliedAt': datetime.datetime(2023, 9, 15, 20, 22, 53),
#   'appVersion': '4.34',
#   'Sentiment_Score': 1.7},
#  {'reviewId': '1293786e-311d-4ee1-83d9-83ab0679af82',
#   'userName': 'Julia Squires',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW966tdfJsPYADdULls-aqkboeK-wvdprdHZ4TWoCddQA',
#   'content': 'Getting kicked in and out',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 14, 21, 56, 3),
#   'replyContent': "Hi Julia, I'm sorry you are experiencing issues with our app. Please try to uninstall then reinstall the app on your device, and if the issue persists please call us at 1-800-769-2555, we can help you out.- Chris\n",
#   'repliedAt': datetime.datetime(2023, 9, 15, 20, 21, 19),
#   'appVersion': '4.34',
#   'Sentiment_Score': 0},
#  {'reviewId': '1901402b-cbe6-4afc-a42e-18404087fa7b',
#   'userName': 'nick moore',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXjBgGxku8Aceg7vuPfb02PpDcn4U2XEAWs-SibkJmMDQ',
#   'content': 'Loads horribly slow',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 14, 21, 27, 46),
#   'replyContent': 'Hi Nick, thanks for taking the time to provide your feedback. I have passed this along to our developers. -Chris\n',
#   'repliedAt': datetime.datetime(2023, 9, 15, 20, 20, 24),
#   'appVersion': '4.34',
#   'Sentiment_Score': -2.4},
#  {'reviewId': '26d248a2-7761-4386-9c41-007fe54a6b9b',
#   'userName': 'Marcin Bizon',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUdcVafOm3GQcZ5XBfsJh1CyThwPhGZUqhcTqi_U-ea7qc',
#   'content': "Trying to login all the time 2 step verification and I don't get any verification codes from the stupid rbc joke. Tried everything. Stupid joke suck",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 14, 5, 48, 15),
#   'replyContent': 'Thank you for your time and feedback. Please text RBC to 722652 to opt in. If no response please reach out to your cellphone provider as they may be blocking the SMS from coming in. -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 14, 21, 8, 31),
#   'appVersion': '4.34',
#   'Sentiment_Score': -5.5},
#  {'reviewId': '944a3fe9-b25e-4c45-b483-af207e9bed63',
#   'userName': 'AJ SCHOFIELD',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJoR0BE9EfbxalbU5T_OnieZlzNEh4ZQvdVkriKvIr4=mo',
#   'content': 'Been using for a long time and have been very happy with the app',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 13, 15, 6, 37),
#   'replyContent': 'Hi, thank you for taking the time to provide us your great feedback and rating! - Andre',
#   'repliedAt': datetime.datetime(2023, 9, 13, 15, 42, 59),
#   'appVersion': '4.34',
#   'Sentiment_Score': 2.7},
#  {'reviewId': '3841efea-f1bd-4660-97a3-ccdca2debb95',
#   'userName': 'christine joy leonor',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJTdLLhaoSJIuqL5pXssttuz1X32iLGAoyBl-KrMttO=mo',
#   'content': 'Rbc customer service sucks.. i need a help and i waited for 1 hr. And 6 mins just to tell me he cant help me and need to go to the nearest bank to get a pincode that i dont have in my credit card. Whats the sense of asking me all the security questions???! Made my day pissed off!',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 13, 14, 53, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.34',
#   'Sentiment_Score': 3.2},
#  {'reviewId': '52972490-da62-4423-9ca6-871f80b295a2',
#   'userName': 'Joel Coke',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ8bK2GqUMXQkMZiU0nrVCCj275-A2JAHbGODLCE_8=mo',
#   'content': 'S j66',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.18',
#   'at': datetime.datetime(2023, 9, 12, 21, 30, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.18',
#   'Sentiment_Score': 0},
#  {'reviewId': '587ed67e-3680-4756-b932-3affdc1b4d08',
#   'userName': 'SADAQUAT ALI',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL4qb_YyMq4qfV_LjJKhGz5jiDlK7b5MeM1gpv7kU1F=mo',
#   'content': 'Easy and fast',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 12, 20, 51, 9),
#   'replyContent': 'Hi, thank you for taking the time to provide us your great feedback and rating! - Andre',
#   'repliedAt': datetime.datetime(2023, 9, 13, 15, 40, 1),
#   'appVersion': '4.34',
#   'Sentiment_Score': 1.9},
#  {'reviewId': '67441669-5dde-467c-9df9-e7db96f75106',
#   'userName': 'Manos Reyes',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL4KWxJYIguxAXcFkQR6YwBZT7PUpxEhtmynNBSnfgn=mo',
#   'content': 'Very good.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 11, 3, 22),
#   'replyContent': 'Thank you for the awesome review! -- Ray',
#   'repliedAt': datetime.datetime(2023, 9, 11, 20, 44, 7),
#   'appVersion': '4.34',
#   'Sentiment_Score': 0},
#  {'reviewId': 'c5a2e219-938a-4e5d-a6c7-aa01bbe77f93',
#   'userName': 'Priyesh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI6EwL9mQFDgwbCl_R5I03ucDtRFTa94Es7v-oEt07K=mo',
#   'content': "Unable to change my Trusted Device. Stupid 2-way verification status shows its off both on website and in the App, but still asks me to confirm login from my previous device or using text message. When I try to push confirmation from web to new device it says Technical Difficulties. Stupid! It should accept the device that has Registered cellphone. Credit Card account show wrong name of the provider. It's been pending from last two years and developers/testers have failed to fix the issue.",
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '4.34',
#   'at': datetime.datetime(2023, 9, 10, 6, 43, 31),
#   'replyContent': 'I am sorry for the inconvenience this is causing you, our development teams continue to work on the issue and hope to have a fix released very soon. - Chris',
#   'repliedAt': datetime.datetime(2022, 1, 31, 20, 36, 30),
#   'appVersion': '4.34',
#   'Sentiment_Score': -1.4999999999999996},
#  {'reviewId': '6340951c-34fb-41a9-aeb7-39b935b5e6df',
# ...
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 17, 20, 33, 8),
#   'replyContent': "Hi Angel, I'm terribly sorry to hear these have been your experiences. I have shared your comments with our management team for them to look into. - Chris",
#   'repliedAt': datetime.datetime(2022, 8, 19, 17, 49, 27),
#   'appVersion': '4.24',
#   'Sentiment_Score': 0},
#  {'reviewId': '7934c44b-c174-4b30-8524-1e3169334e14',
#   'userName': 'doyle kukkik',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVNuebKvFj7MDT-KBbPwf6MKGrC29KTACLiyGiBh2K8Qw',
#   'content': '🤘',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 17, 15, 46, 19),
#   'replyContent': 'Hi Doyle, thanks for the review! - Chris',
#   'repliedAt': datetime.datetime(2022, 8, 19, 17, 46, 30),
#   'appVersion': '4.24',
#   'Sentiment_Score': 0},
#  {'reviewId': '5ffc51f1-22b7-438f-a5e1-5e19ee05aff7',
#   'userName': 'R N',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWUF7LcZeCupYo-bGgdnPRlkGft59jZqEKCDw2sER3TuUA',
#   'content': "App works okay. No crashes or anything. Changed to a new phone Samsung S22, and made it the trusted device. The phone doesn't show prompts when signing into my pc and I have to use another method for 2 factor authentication. Issue has been solved. Thank you",
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 16, 14, 19, 54),
#   'replyContent': 'Hi Ray, sorry you are having this problem. We can help you out with this, please call us at 1-800-769-2555. - Chris',
#   'repliedAt': datetime.datetime(2022, 8, 12, 20, 10, 4),
#   'appVersion': '4.24',
#   'Sentiment_Score': 2.4000000000000004},
#  {'reviewId': 'bdbcc22e-e7f8-4035-8dbc-3f6fba38f472',
#   'userName': 'Nicole Charlebois',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK_aK1XbyHKfB2xnFdEalVTAlo-goy3E1uW000u309q=mo',
#   'content': 'Love this app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 16, 0, 42, 46),
#   'replyContent': 'Hi Nicole, thank you for the great review! - Chris',
#   'repliedAt': datetime.datetime(2022, 8, 19, 17, 35, 27),
#   'appVersion': '4.24',
#   'Sentiment_Score': 3.2},
#  {'reviewId': 'f7c93412-e5a1-4fd7-b052-662cd9c45d37',
#   'userName': 'M K',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWyC4GQbPcfFLrVPVSlpT69ZIDZYWn2BnpVCEm4Ry0tNXhy',
#   'content': 'Chronic pop up tips are a point of frustration. Enough already. And why cant I pay my RBC Visa bill when I click on pay bills?? EDIT: developer followed up - changing to 4 stars',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 15, 13, 16, 26),
#   'replyContent': "Hi there, I'm sorry for any frustration our app has caused. I have passed your feedback along to our developers for consideration. - Chris",
#   'repliedAt': datetime.datetime(2022, 8, 12, 20, 12, 50),
#   'appVersion': '4.24',
#   'Sentiment_Score': -0.8},
#  {'reviewId': '71c326c3-b954-4890-876a-456607b70e45',
#   'userName': 'Marvin Lu',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVm5GK_q8lCliLE9vcEp-PHoKyD_tp44J-JRF70EE8_4F8',
#   'content': 'App is partially functional. Biometric logging in is no longer available.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 13, 10, 27, 14),
#   'replyContent': "Thank you for your time and feedback. I'm sorry you are having issues with the app. Please reach out to our customer support at 1-800-769-2555 so we may look into this for you -- Ray",
#   'repliedAt': datetime.datetime(2022, 8, 15, 20, 4, 39),
#   'appVersion': '4.24',
#   'Sentiment_Score': -1.2},
#  {'reviewId': 'f94a5615-b271-4eaf-8aac-e1748e824e78',
#   'userName': 'Emily Beisick',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVloBBMjR1KP3EafEaY2_thlteAqJmaqgJ5-nBb0xnQ50M',
#   'content': "It Is a very good app. Just don't get scammed!",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 12, 6, 42, 54),
#   'replyContent': "Hi Emily, thanks for the review. If you have any questions or concerns surrounding security we'd be happy to help, you can reach us at 1-800-769-2555. - Chris",
#   'repliedAt': datetime.datetime(2022, 8, 12, 20, 16, 50),
#   'appVersion': '4.24',
#   'Sentiment_Score': 1.9},
#  {'reviewId': 'bbc24dbe-2c5d-4bdc-961d-1d8f0fc6ed01',
#   'userName': 'Cherylle Rodrigo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLEpcmctlNImKm0fN0hKapbk7bbNgNLeXQJxhd53otP=mo',
#   'content': "Can't open for 5 days now always technical issues.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 10, 22, 20, 52),
#   'replyContent': "Hi Cherylle, sorry to hear you are having ongoing issues with the app. Please try to reinstall the app on your device, and if the issue persists please call us at 1-800-769-2555, we'd be happy to help. - Chris",
#   'repliedAt': datetime.datetime(2022, 8, 12, 20, 6, 19),
#   'appVersion': '4.24',
#   'Sentiment_Score': 0},
#  {'reviewId': '64788080-9a40-46e2-badc-2a9e8a7033c1',
#   'userName': 'Aylene Sun',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKyjKGV4ZwOiXYaB0tRs6vMNsQ70-tYbaiY1vQJgv7CSA=mo',
#   'content': 'If you have RBC, change it. Already had problems with the bank and now the app. You just lost a customer',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 10, 22, 10, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.24',
#   'Sentiment_Score': -3.0},
#  {'reviewId': '677f3efb-fdc2-4c7b-be8f-5f1276e37ec4',
#   'userName': 'Derek Argon',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW9hrbUafMGP2OX7yMP63ZMXZA639J2WQym-s3lnH1WB0m2',
#   'content': "Doesn't work",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 10, 4, 31, 7),
#   'replyContent': "Hi there, sorry to hear the app isn't working for you. We'd love to help you out, please give us a call at 1-800-769-2555. - Chris",
#   'repliedAt': datetime.datetime(2022, 8, 12, 20, 4, 25),
#   'appVersion': '4.24',
#   'Sentiment_Score': 0},
#  {'reviewId': '9bd0d5af-593b-4647-bcf8-4686782dfc88',
#   'userName': 'BLACK FOX',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUBM_d6jHMLmxzmEcGzl1UOGHWQNWTuoEP2YWianNwQHRo',
#   'content': '🤯this is the sh🤬🤬tie🤬t bank in the world. call them impossible reset password also impossible',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 9, 23, 49, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.24',
#   'Sentiment_Score': 0},
#  {'reviewId': 'b6c487ad-144a-41a4-a3dc-50b2ab0c7887',
#   'userName': 'Wayne Forhan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJWVR8zoteLorYOdJwO7j5Y0Kcn8pWojOWzQ4blW68=mo',
#   'content': 'Works great',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 9, 19, 22, 44),
#   'replyContent': 'Hi Wayne, thanks for the fantastic review! - Chris',
#   'repliedAt': datetime.datetime(2022, 8, 12, 20, 2, 36),
#   'appVersion': '4.24',
#   'Sentiment_Score': 3.1},
#  {'reviewId': '611ba633-3b61-4192-b162-91ec2baf1b1f',
#   'userName': 'KR Tilley',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKghgAAyGCw-Ljkco5JKu6FxM0lvDOYg-bhleQaelVH=mo',
#   'content': "It's not working at all .. won't allow sign in , says details are incorrect every time After posting review , was responded to by developer and now the app finally is working correctly ..still unsure what the original problem was",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 9, 10, 15, 20),
#   'replyContent': "Hi, I'm glad to hear the app is now working for you! - Chris",
#   'repliedAt': datetime.datetime(2022, 8, 12, 20, 1, 40),
#   'appVersion': '4.24',
#   'Sentiment_Score': -0.4999999999999998},
#  {'reviewId': '6473375e-5ce6-4045-abce-8e0e6f30c549',
#   'userName': 'Jazmine Smith',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ12wxm6vO4xZMGQs7JdNUcbSwRAUP0sy2iRyWzgTj_6A=mo',
#   'content': 'Worst bank ever...the app keeps screwing up...then have to wait 45 mins just to speak to someone to help you with your online banking app....I cannot stand this!',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 8, 7, 5, 18, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'Sentiment_Score': -2.3},
#  {'reviewId': '000f50ce-ab8a-4905-94da-21eb284bd418',
#   'userName': 'Frederick To',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVVnklb09k5-hE0zfExOmcsAWUK2oGa5g0Tb6x3FY6KNsA',
#   'content': "It used to be useful for deposit check online. However out of sudden since last month it could not accept the image taken but always showing a warning message. I couldn't get around the error no matter how hard I tried, but could only chose to accept it manually, bearing the risk that it might be rejected. Very frustrating.",
#   'score': 2,
#   'thumbsUpCount': 17,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 7, 2, 6, 29),
#   'replyContent': 'Thank you for your time and feedback. There was a known and should of been corrected with the new update version 4.24. Please advise if issue still persist. -- Ray',
#   'repliedAt': datetime.datetime(2022, 8, 8, 19, 48, 41),
#   'appVersion': '4.24',
#   'Sentiment_Score': -0.5999999999999999},
#  {'reviewId': '118424bd-acb0-47c2-abdd-e06602fae3e5',
#   'userName': 'massi sadat officials channel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKjugst-1Q6RDuGPcZ8TrJydeFTZi3ru2ZPNM7GeiFd=mo',
#   'content': "Can't replace my credit card using online banking or mobile app. It says please try again later damn damn 😤",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 6, 14, 18, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.24',
#   'Sentiment_Score': -0.49999999999999956},
#  {'reviewId': 'cdef2ee9-b1b5-4a19-be70-3d1e13a3ec06',
#   'userName': 'Kristal Moore',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXOnpY_77Ku7Q9Q5xUItLTUlF7HzwG3K5H9dRkguEs8YKg',
#   'content': 'I am in consumer counseling.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.19',
#   'at': datetime.datetime(2022, 8, 4, 2, 7, 19),
#   'replyContent': "Hi Kristal, we'd love to help you out, please give us a call at 1-800-769-2511. - Chris",
#   'repliedAt': datetime.datetime(2022, 5, 27, 20, 36, 21),
#   'appVersion': '4.19',
#   'Sentiment_Score': 0},
#  {'reviewId': 'b1eb8400-b25a-46ab-824a-30c01521e642',
#   'userName': 'Eric Morel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKfUYczKy9qm5od9HpLJRBc4VE7TAbL5FZG0F3lE52y=mo',
#   'content': "Hi, Why can't you make it more like the website? Missing a lot of features that are only available from the website. Like, the complete transfer history.... We need the international transfers too. I always have to login on my computer to go and check if a transaction has gone through. Thanks",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 2, 23, 28, 46),
#   'replyContent': 'Thank you for your time and feedback. I have passed this along to our developers. -- Ray',
#   'repliedAt': datetime.datetime(2022, 8, 5, 21, 21, 27),
#   'appVersion': '4.24',
#   'Sentiment_Score': 2.2},
#  {'reviewId': '9d749bc2-9268-4826-a82a-be9f61d79c84',
#   'userName': 'Brian Boychuk',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXEmjbyYyikwyw8t0opF7cP837g7EyjdDtXVxfKHfs6S7w',
#   'content': "Used to work fine, then stopped working (can't log in) months ago. It is scary when your bank can't get an app to work correctly. Hope they are better at privacy and security.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '3.10',
#   'at': datetime.datetime(2022, 8, 2, 20, 54, 16),
#   'replyContent': 'Hi Brian, we sincerely apologize for the troubles you’ve had with the app and we’d love to help you. Please call us at 1-800-769-2555. – Eric',
#   'repliedAt': datetime.datetime(2022, 8, 3, 17, 52, 37),
#   'appVersion': '3.10',
#   'Sentiment_Score': 0.6999999999999997},
#  {'reviewId': 'cf82f47d-c487-4418-aead-72e13d124f6b',
#   'userName': 'Tristan Bouffanais',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX7vLkSReA5VDh-E0x5tV6RL2mE8kTP3ZeZWYSERKGbBtc',
#   'content': 'I like money',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 2, 19, 8, 4),
#   'replyContent': 'Hi Tristan, thanks for taking the time to rate us! - Eric',
#   'repliedAt': datetime.datetime(2022, 8, 3, 17, 57, 27),
#   'appVersion': '4.24',
#   'Sentiment_Score': 1.5},
#  {'reviewId': 'fc63e2c0-0319-4cf7-9a2b-fb87537f593b',
#   'userName': 'Ariel Delcourt',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXnIbYGLgl7IBfohrYQg-7pC7LrDqamLBd2LdjQqKp-A3g',
#   'content': 'Never lets me login, horrible',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 8, 2, 17, 17, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.24',
#   'Sentiment_Score': -2.5},
#  {'reviewId': '9a24d136-ef88-44e7-9376-b2334b028f73',
#   'userName': 'Rick Bennett',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKRuCE2a3OJdpK3lV8FKgOyBxmyrBIs7J2pMcZQfzTc=mo',
#   'content': 'Great,have a new phone',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.19',
#   'at': datetime.datetime(2022, 8, 2, 11, 34, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.19',
#   'Sentiment_Score': 0},
#  {'reviewId': '47598063-5fe2-4217-a0eb-8e486346ae19',
#   'userName': 'Myeloxilo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIJuetxWhmv2UZ3qYckfeZzu7THbmXXjk3lLmt9deRw=mo',
#   'content': 'Terrible awful disrespectful. Should go bankrupt as soon as possible.',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.24',
#   'at': datetime.datetime(2022, 7, 31, 21, 29, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.24',
#   'Sentiment_Score': -6.699999999999999},
#  {'reviewId': '5444ce6c-be3d-4fc1-a75b-0b585c6707c6',
#   'userName': 'paolo cugliari',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLylJDLB00y08KUm0ELhX2dten71Oa1qJ1Tn4f3pKAn=mo',
#   'content': 'RBC is terrible. For the 2nd time in about 1.5 months, they\'ve locked my account due to suspicious activity? I verified the transactions being done the 1st time and now they went ahead and locked it a second time for the same stupid reason? RBC has the most ridiculous protocols ever. It\'s like "we don\'t trust you with your money so we\'ll need proof of what you do with it". Pathetic',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.23.1',
#   'at': datetime.datetime(2022, 7, 31, 20, 59, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.23.1',
#   'Sentiment_Score': -4.300000000000001},
#  {'reviewId': 'ef1c89aa-584a-457a-aafb-c4a9c1f97118',
#   'userName': 'Tina Faragalli',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV_0h3vdharVoYIwbL_fSK43XtBhYjAq0WTHZLM2mUkCXk',
#   'content': 'it will not let me see my accounts even after 2 verifications that it is me. uninstalled app and reinstalled twice. will only work if I go through my browser.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.1',
#   'at': datetime.datetime(2022, 7, 31, 19, 45, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.1',
#   'Sentiment_Score': 0},
#  ...]

# %% [markdown]
# # Question 8

# %% [markdown]
# Add a `sentiment_flag` variable to each review. It should be equal to 'pos' if the `sentiment_score` is greater than 0, 'neg' if the `sentiment_score` is less than 0, and 'neu' if the `sentiment_score` is equal to 0.

# %%
for review in rbc_reviews:
  sentiment_score = review['Sentiment_Score']
  if sentiment_score > 0:
    review['sentiment_flag'] = 'pos'
  elif sentiment_score < 0:
    review['sentiment_flag'] = 'neg'
  else:
    review['sentiment_flag'] = 'neu'

# %% [markdown]
# # Question 9

# %% [markdown]
# Add a year variable that indicates what `year` the review is from.

# %%
for review in rbc_reviews:
  review['year'] = review.get('at').year if review.get('at') is not None else None

# %% [markdown]
# # Question 10

# %% [markdown]
# Convert `rbc_reviews` into a Pandas dataframe.

# %%
import pandas as pd
df = pd.DataFrame(rbc_reviews)

# %%
df.head(10)
# Out:
#                                reviewId            userName  \
# 0  4314388d-f571-4ff8-b03a-1ca4b0e15995         Inna Titova
# 1  ed6870f5-d0bb-44f8-9180-e4f07b908fc7           Ben Brash
# 2  1feb549b-9f9c-43d0-9ec8-70917e05c953        Lisa Carlini
# 3  e7809eef-d692-4bb6-9d07-5dd5c67ce995             Al Fred
# 4  dd582b7e-525b-42a6-8473-f0b8401e9d75      Sophie Frenkel
# 5  349d11b2-47e6-403c-9c82-0ef33a2f3be7        Austin Short
# 6  4f1928d4-8adf-4f83-84be-2ade15c6544a       A Google user
# 7  ef45e0e6-c0a9-4473-bdae-18e6e412d34b        Jason Rapsey
# 8  2fb629f0-f378-44aa-b133-eef558d893f1    Srivick Donepudi
# 9  60826c6d-9071-4011-9143-28c9a5491202  Lambert M.J. Andre
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
# 5  https://play-lh.googleusercontent.com/a-/ALV-U...
# 6  https://play-lh.googleusercontent.com/EGemoI2N...
# 7  https://play-lh.googleusercontent.com/a-/ALV-U...
# 8  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                                    Very convenient      5              0
# 1  The app mostly works I guess. But it annoys me...      2              0
# 2  The app is fine except for the fact that you c...      3              0
# 3  It works as expected. Only a couple of times c...      5              0
# 4  Deleted this app from my S22 and now from my o...      1              0
# 5  budgets are useless and do not work. etransfer...      1              4
# 6                       Hello top looking for bottom      5              0
# 7  I have been an RBC customer for a whole 6 days...      1              0
# 8                                     Really helpful      5              0
# 9                  +++++ROYAL SAYS IT ALL+++++ *****      5              0
#
#   reviewCreatedVersion                  at  \
# 0                 4.34 2023-10-08 22:29:43
# 1                 4.34 2023-10-07 21:00:06
# 2                 4.34 2023-10-07 14:50:09
# 3                 4.34 2023-10-07 04:38:48
# 4                 None 2023-10-06 21:45:06
# 5                 4.34 2023-10-06 15:56:30
# 6                 4.34 2023-10-06 10:46:38
# 7                 4.34 2023-10-05 16:18:55
# 8                 4.34 2023-10-05 14:53:40
# 9                 4.34 2023-10-05 04:58:30
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
# 5  Hi Austin, we appreciate you taking the time t... 2023-10-06 21:05:50
# 6                                               None                 NaT
# 7  Thank you for your time and feedback. Please r... 2023-10-05 19:50:32
# 8           Thank you for the awesome review! -- Ray 2023-10-05 19:45:38
# 9          Thank you for the awesome review!! -- Ray 2023-10-05 19:45:04
#
#   appVersion  Sentiment_Score sentiment_flag  year
# 0       4.34              0.0            neu  2023
# 1       4.34             -3.8            neg  2023
# 2       4.34              1.3            pos  2023
# 3       4.34              0.0            neu  2023
# 4       None              0.7            pos  2023
# 5       4.34             -0.1            neg  2023
# 6       4.34              0.8            pos  2023
# 7       4.34             -1.1            neg  2023
# 8       4.34              1.8            pos  2023
# 9       4.34              0.0            neu  2023

# %% [markdown]
# # Question 11

# %% [markdown]
# Calculate the percentage of reviews that are positive, negative, and neutral for each year: 2019, 2020, 2021, 2022, 2023.

# %%
years_to_filter = [2019, 2020, 2021, 2022, 2023]

# filter the DataFrame
filtered_df = df[df['year'].isin(years_to_filter)]

#Using group by to group reviews on year and get the total count review for that year
sentiment_total_review=filtered_df.groupby('year')['sentiment_flag'].count()

#Using group by to group reviews on year and get the count of different reviews for that year
sentiment_value_review=filtered_df.groupby('year')['sentiment_flag'].value_counts()

#Calculate percentage
sentiment_review_percentage = (sentiment_value_review / sentiment_total_review) * 100
print(sentiment_review_percentage)
# Out:
# year  sentiment_flag
# 2019  pos               59.197908
#       neg               20.401046
#       neu               20.401046
# 2020  pos               57.385399
#       neu               21.392190
#       neg               21.222411
# 2021  pos               52.237136
#       neg               25.055928
#       neu               22.706935
# 2022  pos               47.635934
#       neg               28.605201
#       neu               23.758865
# 2023  pos               48.878205
#       neg               28.205128
#       neu               22.916667
# Name: sentiment_flag, dtype: float64
